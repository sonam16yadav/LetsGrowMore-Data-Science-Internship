# %% [markdown]
# #### Lets Grow More
# #### Name - Sonamkumari Yadav
# #### Data Science Intern
# #### Intermediate leval-TASK-2-PREDICTION-USING-DECISION-TREE-ALGORITHM-LEVEL-INTERMEDIATE

# %% [markdown]
# ### Importing Necessary Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.tree import DecisionTreeClassifier

# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# ##### Reading Data

# %%
iris=sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.shape
# Out:
# (150, 5)

# %% [markdown]
# ### Getting Basic Data Information

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
X = iris[['sepal_length','sepal_width','petal_length','petal_width']].values
X[0:5]
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2]])

# %%
Y = iris['species']
Y[0:5]
# Out:
# 0    setosa
# 1    setosa
# 2    setosa
# 3    setosa
# 4    setosa
# Name: species, dtype: object

# %%
from sklearn.model_selection import train_test_split
X_trainset, X_testset, Y_trainset, Y_testset = train_test_splittrain_X, test_X, train_y, test_y= train_test_split(X,Y, test_size=0.3)

# %%
SpeciesTree = DecisionTreeClassifier(criterion = 'entropy', max_depth = 4)
SpeciesTree
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4)

# %%
SpeciesTree.fit(X_trainset, Y_trainset)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4)

# %% [markdown]
# ##### Making Prediction

# %%
predTree = SpeciesTree.predict(X_testset)

# %%
print(predTree [0:5])
print(Y_testset[0:5])
# Out:
# ['setosa' 'setosa' 'virginica' 'versicolor' 'setosa']
# 19         setosa
# 28         setosa
# 149     virginica
# 92     versicolor
# 16         setosa
# Name: species, dtype: object

# %% [markdown]
# ##### Evaluation

# %%
## Making Predictionfrom sklearn import metrics
from sklearn import metrics
print("Accuracy: ",metrics.accuracy_score(Y_testset, predTree))
# Out:
# Accuracy:  0.9333333333333333

# %% [markdown]
# ##### Decision Tree Visualization

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
fn = iris.columns[1:5]
cn = iris["species"].unique().tolist()
SpeciesTree.fit(X,Y)
fig, axes = plt.subplots(nrows = 1,ncols = 1, figsize = (10,10), dpi =400)
tree.plot_tree(SpeciesTree,feature_names = fn, class_names = cn, filled = True);

# %% [markdown]
# #### Predicting Species for Set of Values

# %%
X_new = [[6.3,3.0,1.3,0.2]]

predTree = SpeciesTree.predict(X_new)
predTree
# Out:
# array(['setosa'], dtype=object)
